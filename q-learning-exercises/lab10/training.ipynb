# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('train.csv')
dataframe.tail()
# Out:
#                loss
# 19631  37338.203125
# 19632   5137.094238
# 19633     -2.169756
# 19634   1943.551514
# 19635  12033.925781

# %%
plt.plot(dataframe['loss'].rolling(window=100).mean())
plt.show()
